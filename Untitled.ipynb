# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('athletes.csv')

# Display the loaded data
df
# Out:
#         athlete_id             name               region  \
# 0           2554.0        Pj Ablang           South West
# 1           3517.0    Derek Abdella                  NaN
# 2           4691.0              NaN                  NaN
# 3           5164.0      Abo Brandon  Southern California
# 4           5286.0      Bryce Abbey                  NaN
# ...            ...              ...                  ...
# 423001    574489.0       Odo Renata        Latin America
# 423002    585696.0    Lozzie Trevor            Australia
# 423003    608828.0    Marisol Smith           North West
# 423004    628881.0  Pedrini Morgane               Europe
# 423005    631847.0       Eden Kenny  Northern California
#
#                            team              affiliate  gender   age  height  \
# 0                   Double Edge   Double Edge CrossFit    Male  24.0    70.0
# 1                           NaN                    NaN    Male  42.0    70.0
# ...

# %%
# Drop rows with NaN values
df.dropna(inplace=True)

# Print the resulting DataFrame
df
# Out:
#         athlete_id              name         region  \
# 102         2720.0      Justin Adams  South Central
# 110         6922.0    Daniel Adamson     South West
# 116        12563.0  Steven Lee Adams   Mid Atlantic
# 238        24943.0        Greg Adler   Mid Atlantic
# 304         3066.0     Luke Ahlfield  North Central
# ...            ...               ...            ...
# 372328     22627.0     Keith McGuire     South East
# 375133    103943.0     Robert Payton     South East
# 380392      4932.0      Troy Straith    Canada West
# 382760    110296.0    Dennis Walczyk     South West
# 421423    506969.0    Heather Garcia  North Central
#
#                              team                  affiliate  gender   age  \
# 102             Woodward CrossFit          Woodward CrossFit    Male  24.0
# 110            CrossFit The Point         CrossFit The Point    Male  31.0
# 116                CrossFit Kaiju             CrossFit Kaiju    Male  37.0
# ...

# %%
df.to_csv('crossfit_games_athletes.csv', index=False)
